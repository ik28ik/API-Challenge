# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy as owm

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 617

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
settings = {"units": "imperial", "appid": api_key}

cities_weatherpy =pd.DataFrame(columns = ["City","Cloudiness", "Country", "Date", 
                                          "Humidity", "Lat","Lng", "Max Temp", "Wind Speed"])

count = 1 
err = 0 
sets = 0 
index = 0 


t0 =time.time()

print(f'Beginning Data Retrieval \n ........................')

for city in cities:
    
    try:
        city1 = city.replace(" ", "%20") 
        print(f'Processing Record {count} of Set {sets} | {city}' )

        city_stats = owm.get_current(city, **settings)
        cities_weatherpy.set_value(index, "City", city_stats["name"])
        cities_weatherpy.set_value(index, "Cloudiness", city_stats("clouds.all"))
        cities_weatherpy.set_value(index, "Country", city_stats("sys.country"))
        cities_weatherpy.set_value(index, "Date", city_stats("dt"))
        cities_weatherpy.set_value(index, "Max Temp", city_stats("main.temp_max"))
        cities_weatherpy.set_value(index, "Wind Speed", city_stats("wind.speed"))
        cities_weatherpy.set_value(index, "Lat", city_stats("coord.lat"))
        cities_weatherpy.set_value(index, "Lng", city_stats("coord.lon"))
        cities_weatherpy.set_value(index, "Humidity", city_stats("main.humidity"))
        
        index = index +1 
    except Exception as e:
        print('City not found. Skipping...')
        
        err= err+1
    count = count+1
    
    if count == 51: 
        t1=time.time()
        count = 1 
        sets = sets+1
        time.sleep(60-(t1-t0))
        t0=time.time()

print("........................\n End of Data Retrieval \n ........................")
# Out:
# Beginning Data Retrieval
#  ........................
# Processing Record 1 of Set 0 | albany
# Processing Record 2 of Set 0 | cessnock
# Processing Record 3 of Set 0 | atuona
# C:\Users\Irisi\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Irisi\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Irisi\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Irisi\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Irisi\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Irisi\Anaconda3\lib\site-packages\ipykernel_launcher.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Irisi\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Irisi\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Irisi\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Processing Record 4 of Set 0 | kikwit
# Processing Record 5 of Set 0 | ushuaia
# Processing Record 6 of Set 0 | sao miguel do araguaia
# Processing Record 7 of Set 0 | ngukurr
# City not found. Skipping...
# Processing Record 8 of Set 0 | cabo san lucas
# Processing Record 9 of Set 0 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 0 | college
# Processing Record 11 of Set 0 | nueva guinea
# Processing Record 12 of Set 0 | marsh harbour
# Processing Record 13 of Set 0 | mjolby
# Processing Record 14 of Set 0 | desaguadero
# Processing Record 15 of Set 0 | sabang
# Processing Record 16 of Set 0 | tuktoyaktuk
# Processing Record 17 of Set 0 | puerto ayora
# Processing Record 18 of Set 0 | busselton
# Processing Record 19 of Set 0 | meulaboh
# Processing Record 20 of Set 0 | bluff
# Processing Record 21 of Set 0 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 0 | lisakovsk
# Processing Record 23 of Set 0 | punta arenas
# Processing Record 24 of Set 0 | mataura
# Processing Record 25 of Set 0 | port alfred
# Processing Record 26 of Set 0 | kapaa
# Processing Record 27 of Set 0 | jamestown
# Processing Record 28 of Set 0 | pacific grove
# Processing Record 29 of Set 0 | tasiilaq
# Processing Record 30 of Set 0 | lebu
# Processing Record 31 of Set 0 | bethel
# Processing Record 32 of Set 0 | vila velha
# Processing Record 33 of Set 0 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 0 | hlatikulu
# Processing Record 35 of Set 0 | pimenta bueno
# Processing Record 36 of Set 0 | rocha
# Processing Record 37 of Set 0 | muros
# Processing Record 38 of Set 0 | port elizabeth
# Processing Record 39 of Set 0 | rikitea
# Processing Record 40 of Set 0 | roma
# Processing Record 41 of Set 0 | yanan
# City not found. Skipping...
# Processing Record 42 of Set 0 | dunedin
# Processing Record 43 of Set 0 | gari
# Processing Record 44 of Set 0 | capannori
# Processing Record 45 of Set 0 | gamba
# Processing Record 46 of Set 0 | mahebourg
# Processing Record 47 of Set 0 | nikolskoye
# Processing Record 48 of Set 0 | coihaique
# Processing Record 49 of Set 0 | ancud
# Processing Record 50 of Set 0 | salinopolis
# Processing Record 1 of Set 1 | buraydah
# Processing Record 2 of Set 1 | pisco
# Processing Record 3 of Set 1 | kishtwar
# Processing Record 4 of Set 1 | upernavik
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | natal
# Processing Record 7 of Set 1 | labuan
# Processing Record 8 of Set 1 | saint george
# Processing Record 9 of Set 1 | korla
# City not found. Skipping...
# Processing Record 10 of Set 1 | saint-philippe
# Processing Record 11 of Set 1 | faanui
# Processing Record 12 of Set 1 | jalu
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | athabasca
# Processing Record 15 of Set 1 | antsohihy
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | carnarvon
# Processing Record 18 of Set 1 | okha
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | paita
# Processing Record 21 of Set 1 | ereymentau
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | bengkulu
# City not found. Skipping...
# Processing Record 24 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 1 | lamar
# Processing Record 26 of Set 1 | bambous virieux
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | umm bab
# Processing Record 29 of Set 1 | taoudenni
# Processing Record 30 of Set 1 | honningsvag
# Processing Record 31 of Set 1 | magadan
# Processing Record 32 of Set 1 | ambon
# Processing Record 33 of Set 1 | lumeje
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | tacana
# Processing Record 36 of Set 1 | ponta do sol
# Processing Record 37 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 1 | bukachacha
# Processing Record 39 of Set 1 | kerki
# City not found. Skipping...
# Processing Record 40 of Set 1 | arman
# Processing Record 41 of Set 1 | sebastian
# Processing Record 42 of Set 1 | manakara
# Processing Record 43 of Set 1 | emerald
# Processing Record 44 of Set 1 | esperance
# Processing Record 45 of Set 1 | ilulissat
# Processing Record 46 of Set 1 | clyde river
# Processing Record 47 of Set 1 | matagami
# Processing Record 48 of Set 1 | mao
# Processing Record 49 of Set 1 | oinacu
# Processing Record 50 of Set 1 | constitucion
# Processing Record 1 of Set 2 | dom pedro
# City not found. Skipping...
# Processing Record 2 of Set 2 | castro
# Processing Record 3 of Set 2 | bambanglipuro
# Processing Record 4 of Set 2 | lorengau
# Processing Record 5 of Set 2 | bayir
# Processing Record 6 of Set 2 | hirara
# Processing Record 7 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | sobolevo
# Processing Record 10 of Set 2 | avarua
# Processing Record 11 of Set 2 | trinidad
# Processing Record 12 of Set 2 | havelock
# Processing Record 13 of Set 2 | new norfolk
# Processing Record 14 of Set 2 | karlskrona
# Processing Record 15 of Set 2 | ferrol
# Processing Record 16 of Set 2 | morondava
# Processing Record 17 of Set 2 | east london
# Processing Record 18 of Set 2 | banda aceh
# Processing Record 19 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 2 | los llanos de aridane
# Processing Record 21 of Set 2 | yar-sale
# Processing Record 22 of Set 2 | russell
# Processing Record 23 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 2 | husavik
# Processing Record 25 of Set 2 | kavieng
# Processing Record 26 of Set 2 | dikson
# Processing Record 27 of Set 2 | baykit
# Processing Record 28 of Set 2 | boa vista
# Processing Record 29 of Set 2 | guerrero negro
# Processing Record 30 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 2 | christchurch
# Processing Record 32 of Set 2 | lae
# Processing Record 33 of Set 2 | salta
# Processing Record 34 of Set 2 | norman wells
# Processing Record 35 of Set 2 | lake city
# Processing Record 36 of Set 2 | osorno
# Processing Record 37 of Set 2 | mount isa
# Processing Record 38 of Set 2 | nyuksenitsa
# Processing Record 39 of Set 2 | bozovici
# Processing Record 40 of Set 2 | cayenne
# Processing Record 41 of Set 2 | vila franca do campo
# Processing Record 42 of Set 2 | abu zabad
# Processing Record 43 of Set 2 | chokurdakh
# Processing Record 44 of Set 2 | khatanga
# Processing Record 45 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 46 of Set
# Processing Record 33 of Set 4 | beyneu
# Processing Record 34 of Set 4 | port hedland
# Processing Record 35 of Set 4 | tuatapere
# Processing Record 36 of Set 4 | ambilobe
# Processing Record 37 of Set 4 | half moon bay
# Processing Record 38 of Set 4 | pitsunda
# Processing Record 39 of Set 4 | filadelfia
# Processing Record 40 of Set 4 | ekhabi
# Processing Record 41 of Set 4 | pangnirtung
# Processing Record 42 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 43 of Set 4 | rio gallegos
# Processing Record 44 of Set 4 | iqaluit
# Processing Record 45 of Set 4 | tala
# Processing Record 46 of Set 4 | cidreira
# Processing Record 47 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 48 of Set 4 | the valley
# Processing Record 49 of Set 4 | inhambane
# Processing Record 50 of Set 4 | talnakh
# Processing Record 1 of Set 5 | ondjiva
# Processing Record 2 of Set 5 | najran
# Processing Record 3 of Set 5 | vanimo
# Processing Record 4 of Set 5 | stornoway
# City not found. Skipping...
# Processing Record 5 of Set 5 | jubayl
# City not found. Skipping...
# Processing Record 6 of Set 5 | valparaiso
# Processing Record 7 of Set 5 | airai
# Processing Record 8 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 5 | kluang
# Processing Record 10 of Set 5 | nioro
# Processing Record 11 of Set 5 | san andres del rabanedo
# Processing Record 12 of Set 5 | hasaki
# Processing Record 13 of Set 5 | viedma
# Processing Record 14 of Set 5 | cuamba
# Processing Record 15 of Set 5 | ukiah
# Processing Record 16 of Set 5 | nieuwpoort
# Processing Record 17 of Set 5 | yining
# Processing Record 18 of Set 5 | coquimbo
# Processing Record 19 of Set 5 | saldanha
# Processing Record 20 of Set 5 | brigham city
# Processing Record 21 of Set 5 | mukhen
# Processing Record 22 of Set 5 | kiunga
# Processing Record 23 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 5 | san carlos de bariloche
# Processing Record 25 of Set 5 | san felipe
# Processing Record 26 of Set 5 | tarpon springs
# Processing Record 27 of Set 5 | bom sucesso
# Processing Record 28 of Set 5 | hofn
# Processing Record 29 of Set 5 | port macquarie
# Processing Record 30 of Set 5 | lazaro cardenas
# Processing Record 31 of Set 5 | camden
# Processing Record 32 of Set 5 | san andres
# Processing Record 33 of Set 5 | narsaq
# Processing Record 34 of Set 5 | fort nelson
# Processing Record 35 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 5 | laguna
# Processing Record 37 of Set 5 | vila
# Processing Record 38 of Set 5 | komsomolskiy
# Processing Record 39 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 5 | sangar
# Processing Record 41 of Set 5 | ketchikan
# Processing Record 42 of Set 5 | longhua
# Processing Record 43 of Set 5 | talkha
# Processing Record 44 of Set 5 | banff
# Processing Record 45 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 5 | ahipara
# Processing Record 47 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 5 | usinsk
# Processing Record 50 of Set 5 | champerico
# Processing Record 1 of Set 6 | sao felix do xingu
# Processing Record 2 of Set 6 | luneville
# Processing Record 3 of Set 6 | tarko-sale
# Processing Record 4 of Set 6 | buala
# Processing Record 5 of Set 6 | along
# Processing Record 6 of Set 6 | upington
# Processing Record 7 of Set 6 | dvinskoy
# Processing Record 8 of Set 6 | kytlym
# City not found. Skipping...
# Processing Record 9 of Set 6 | vao
# Processing Record 10 of Set 6 | mwinilunga
# Processing Record 11 of Set 6 | kawalu
# Processing Record 12 of Set 6 | mabini
# Processing Record 13 of Set 6 | tecoanapa
# Processing Record 14 of Set 6 | kedrovyy
# Processing Record 15 of Set 6 | agadir
# Processing Record 16 of Set 6 | baruun-urt
# Processing Record 17 of Set 6 | yuancheng
# City not found. Skipping...
# Processing Record 18 of Set 6 | nome
# Processing Record 19 of Set 6 | kimbe
# Processing Record 20 of Set 6 | livingstone
# Processing Record 21 of Set 6 | coldingham
# Processing Record 22 of Set 6 | kindu
# Processing Record 23 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 6 | evanston
# Processing Record 25 of Set 6 | voh
# Processing Record 26 of Set 6 | ternate
# Processing Record 27 of Set 6 | huarmey
# Processing Record 28 of Set 6 | lakhimpur
# Processing Record 29 of Set 6 | moree
# Processing Record 30 of Set 6 | hualmay
# Processing Record 31 of Set 6 | victoria
# Processing Record 32 of Set 6 | salalah
# Processing Record 33 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 6 | saint-raymond
# Processing Record 35 of Set 6 | erzin
# Processing Record 36 of Set 6 | saskylakh
# Processing Record 37 of Set 6 | tiznit
# Processing Record 38 of Set 6 | santa maria
# Processing Record 39 of Set 6 | belousovka
# Processing Record 40 of Set 6 | ust-nera
# Processing Record 41 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 6 | saint paul
# Processing Record 43 of Set 6 | makakilo city
# Processing Record 44 of Set 6 | synya
# Processing Record 45 of Set 6 | tiruvottiyur
# City not found. Skipping...
# Processing Record 46 of Set 6 | lodingen
# Processing Record 47 of Set 6 | druzhba
# Processing Record 48 of Set 6 | shannon
# Processing Record 49 of Set 6 | avera
# Processing Record 50 of Set 6 | eenhana
# Processing Record 1 of Set 7 | guangyuan
# Processing Record 2 of Set 7 | minas
# Processing Record 3 of Set 7 | el paraiso
# Processing Record 4 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 7 | biskamzha
# Processing Record 6 of Set 7 | souillac
# Processing Record 7 of Set 7 | roznava
# Processing Record 8 of Set 7 | turayf
# Processing Record 9 of Set 7 | havre-saint-pierre
# Processing Record 10 of Set 7 | batemans bay
# Processing Record 11 of Set 7 | chernaya kholunitsa
# Processing Record 12 of Set 7 | yaan
# Processing Record 13 of Set 7 | coahuayana
# Processing Record 14 of Set 7 | eureka
# Processing Record 15 of Set 7 | serebryansk
# Processing Record 16 of Set 7 | poum
# Processing Record 17 of Set 7 | saint-augustin
# Processing Record 18 of Set 7 | namibe
# Processing Record 19 of Set 7 | valdemarpils
# Processing Record 20 of Set 7 | araouane
# Processing Record 21 of Set 7 | kalmunai
# Processing Record 22 of Set 7 | la crosse
# Processing Record 23 of Set 7 | shenkursk
# Processing Record 24 of Set 7 | port hardy
# Processing Record 25 of Set 7 | sinop
# Processing Record 26 of Set 7 | walvis bay
# Processing Record 27 of Set 7 | gat
# Processing Record 28 of Set 7 | khandyga
# Processing Record 29 of Set 7 | shimanovsk
# Processing Record 30 of Set 7 | kurilsk
# Processing Record 31 of Set 7 | kamaishi
# Processing Record 32 of Set 7 | mitsamiouli
# Processing Record 33 of Set 7 | garoua
# Processing Record 34 of Set 7 | tilichiki
# Processing Record 35 of Set 7 | maningrida
# Processing Record 36 of Set 7 | soure
# Processing Record 37 of Set 7 | alice springs
# Processing Record 38 of Set 7 | hamilton
# Processing Record 39 of Set 7 | shingu
# Processing Record 40 of Set 7 | aitape
# Processing Record 41 of Set 7 | selestat
# Processing Record 42 of Set 7 | hambantota
# Processing Record 43 of Set 7 | kahului
# Processing Record 44 of Set 7 
of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 18 of Set 9 | rosenberg
# Processing Record 19 of Set 9 | lata
# Processing Record 20 of Set 9 | stantsionno-oyashinskiy
# Processing Record 21 of Set 9 | labuhan
# Processing Record 22 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 9 | bubaque
# Processing Record 24 of Set 9 | rundu
# Processing Record 25 of Set 9 | chuy
# Processing Record 26 of Set 9 | padang
# Processing Record 27 of Set 9 | mattru
# Processing Record 28 of Set 9 | saint anthony
# Processing Record 29 of Set 9 | lewisporte
# Processing Record 30 of Set 9 | kununurra
# Processing Record 31 of Set 9 | fortuna
# Processing Record 32 of Set 9 | tonj
# City not found. Skipping...
# Processing Record 33 of Set 9 | totma
# Processing Record 34 of Set 9 | canon city
# Processing Record 35 of Set 9 | chambersburg
# Processing Record 36 of Set 9 | orchard homes
# Processing Record 37 of Set 9 | tugulym
# Processing Record 38 of Set 9 | lahaina
# Processing Record 39 of Set 9 | quatre cocos
# Processing Record 40 of Set 9 | thunder bay
# Processing Record 41 of Set 9 | uzhur-4
# City not found. Skipping...
# Processing Record 42 of Set 9 | tiksi
# Processing Record 43 of Set 9 | aksarka
# Processing Record 44 of Set 9 | winnemucca
# Processing Record 45 of Set 9 | eydhafushi
# Processing Record 46 of Set 9 | nabire
# Processing Record 47 of Set 9 | ngunguru
# Processing Record 48 of Set 9 | othonoi
# City not found. Skipping...
# Processing Record 49 of Set 9 | kavaratti
# Processing Record 50 of Set 9 | balabac
# Processing Record 1 of Set 10 | lipovtsy
# Processing Record 2 of Set 10 | asekeyevo
# Processing Record 3 of Set 10 | praya
# Processing Record 4 of Set 10 | wellington
# Processing Record 5 of Set 10 | kopyevo
# City not found. Skipping...
# Processing Record 6 of Set 10 | ntcheu
# Processing Record 7 of Set 10 | eyl
# Processing Record 8 of Set 10 | flinders
# Processing Record 9 of Set 10 | sioux lookout
# Processing Record 10 of Set 10 | miraflores
# Processing Record 11 of Set 10 | llanes
# Processing Record 12 of Set 10 | minot
# Processing Record 13 of Set 10 | mogadishu
# Processing Record 14 of Set 10 | ormara
# Processing Record 15 of Set 10 | stamsund
# City not found. Skipping...
# Processing Record 16 of Set 10 | mackenzie
# Processing Record 17 of Set 10 | canutama
# Processing Record 18 of Set 10 | sinnamary
# Processing Record 19 of Set 10 | shenjiamen
# Processing Record 20 of Set 10 | eirunepe
# Processing Record 21 of Set 10 | trofors
# Processing Record 22 of Set 10 | jardim
# Processing Record 23 of Set 10 | kaduna
# Processing Record 24 of Set 10 | zheleznodorozhnyy
# Processing Record 25 of Set 10 | suao
# City not found. Skipping...
# Processing Record 26 of Set 10 | znamenskoye
# Processing Record 27 of Set 10 | yatou
# Processing Record 28 of Set 10 | saint-joseph
# Processing Record 29 of Set 10 | severo-kurilsk
# Processing Record 30 of Set 10 | sorong
# Processing Record 31 of Set 10 | soe
# Processing Record 32 of Set 10 | mehamn
# Processing Record 33 of Set 10 | olafsvik
# City not found. Skipping...
# Processing Record 34 of Set 10 | ixtapa
# Processing Record 35 of Set 10 | tamuin
# Processing Record 36 of Set 10 | msanga
# Processing Record 37 of Set 10 | una
# Processing Record 38 of Set 10 | grafton
# Processing Record 39 of Set 10 | iranshahr
# Processing Record 40 of Set 10 | la rioja
# Processing Record 41 of Set 10 | kardla
# Processing Record 42 of Set 10 | quartucciu
# Processing Record 43 of Set 10 | hobyo
# Processing Record 44 of Set 10 | huangmei
# Processing Record 45 of Set 10 | lotoshino
# Processing Record 46 of Set 10 | juneau
# Processing Record 47 of Set 10 | ruidoso
# Processing Record 48 of Set 10 | shelbyville
# Processing Record 49 of Set 10 | san patricio
# Processing Record 50 of Set 10 | las choapas
# Processing Record 1 of Set 11 | carbonia
# Processing Record 2 of Set 11 | linares
# Processing Record 3 of Set 11 | merritt island
# Processing Record 4 of Set 11 | andros town
# Processing Record 5 of Set 11 | touros
# Processing Record 6 of Set 11 | kumluca
# Processing Record 7 of Set 11 | fasa
# Processing Record 8 of Set 11 | gewane
# Processing Record 9 of Set 11 | fairbanks
# Processing Record 10 of Set 11 | shikhany
# Processing Record 11 of Set 11 | zhanaozen
# Processing Record 12 of Set 11 | cherskiy
# Processing Record 13 of Set 11 | sao joao da barra
# Processing Record 14 of Set 11 | tura
# Processing Record 15 of Set 11 | zhicheng
# Processing Record 16 of Set 11 | anadyr
# Processing Record 17 of Set 11 | navolato
# Processing Record 18 of Set 11 | panama city
# Processing Record 19 of Set 11 | moussoro
# Processing Record 20 of Set 11 | phan thiet
# Processing Record 21 of Set 11 | brest
# Processing Record 22 of Set 11 | shirokiy
# Processing Record 23 of Set 11 | barra do garcas
# Processing Record 24 of Set 11 | killybegs
# Processing Record 25 of Set 11 | linxia
# Processing Record 26 of Set 11 | yangjiang
# Processing Record 27 of Set 11 | grand-lahou
# Processing Record 28 of Set 11 | safford
# Processing Record 29 of Set 11 | kasama
# Processing Record 30 of Set 11 | kutum
# Processing Record 31 of Set 11 | puebloviejo
# Processing Record 32 of Set 11 | byron bay
# Processing Record 33 of Set 11 | moose factory
# Processing Record 34 of Set 11 | rurrenabaque
# Processing Record 35 of Set 11 | cavalcante
# Processing Record 36 of Set 11 | yemelyanovo
# Processing Record 37 of Set 11 | pierre
# Processing Record 38 of Set 11 | girardot
# Processing Record 39 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 11 | brae
# Processing Record 41 of Set 11 | constantine
# Processing Record 42 of Set 11 | mackay
# Processing Record 43 of Set 11 | bilma
# Processing Record 44 of Set 11 | sakakah
# City not found. Skipping...
# Processing Record 45 of Set 11 | acajutiba
# Processing Record 46 of Set 11 | nishihara
# Processing Record 47 of Set 11 | haveli
# Processing Record 48 of Set 11 | hun
# Processing Record 49 of Set 11 | barranca
# Processing Record 50 of Set 11 | sayyan
# Processing Record 1 of Set 12 | awjilah
# Processing Record 2 of Set 12 | harlingen
# Processing Record 3 of Set 12 | nanortalik
# Processing Record 4 of Set 12 | cockburn town
# Processing Record 5 of Set 12 | abonnema
# Processing Record 6 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 12 | maragogi
# Processing Record 8 of Set 12 | bozoum
# Processing Record 9 of Set 12 | bridgetown
# Processing Record 10 of Set 12 | tazovskiy
# Processing Record 11 of Set 12 | bac lieu
# City not found. Skipping...
# Processing Record 12 of Set 12 | svetlyy
# City not found. Skipping...
# Processing Record 13 of Set 12 | syracuse
# Processing Record 14 of Set 12 | beipiao
# Processing Record 15 of Set 12 | xinzhi
# Processing Record 16 of Set 12 | noshiro
# Processing Record 17 of Set 12 | hernani
# ........................
#  End of Data Retrieval
#  ........................

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_weatherpy.to_csv("cities.csv", encoding="utf-8", index=False)

# %%
cities_weatherpy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 561 entries, 0 to 560
# Data columns (total 9 columns):
# City          561 non-null object
# Cloudiness    561 non-null object
# Country       561 non-null object
# Date          561 non-null object
# Humidity      561 non-null object
# Lat           561 non-null object
# Lng           561 non-null object
# Max Temp      561 non-null object
# Wind Speed    561 non-null object
# dtypes: object(9)
# memory usage: 63.8+ KB

# %%
cities_weatherpy.head(10)
# Out:
#                      City Cloudiness Country        Date Humidity    Lat  \
# 0                  Albany         90      US  1575520209       86  42.65
# 1                Cessnock          0      AU  1575520209       16 -32.83
# 2                  Atuona         21      PF  1575520209       73   -9.8
# 3                  Kikwit         95      CD  1575520209       87  -5.04
# 4                 Ushuaia         75      AR  1575520210       75 -54.81
# 5  Sao Miguel do Araguaia         68      BR  1575520210       94 -13.28
# 6          Cabo San Lucas          5      MX  1575520153       82  22.89
# 7                 College          1      US  1575520210       83  64.86
# 8            Nueva Guinea          6      NI  1575520210       97  11.69
# 9           Marsh Harbour          7      BS  1575520210       54  26.54
#
#       Lng Max Temp Wind Speed
# 0  -73.75       32       1.34
# 1  151.35     91.4      16.11
# 2 -139.03    80.08      12.97
# 3   18.82    73.02       1.52
# 4  -68.31     44.6      28.86
# 5  -50.16    73.02       2.37
# 6 -109.91       72       5.82
# 7  -147.8     -5.8       1.19
# 8  -84.46    70.81       7.34
# 9  -77.06    69.17      12.33

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(cities_weatherpy["Lat"], cities_weatherpy["Max Temp"], marker="o")


plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)


plt.savefig("TemperatureInWeatherPy.png")


plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(cities_weatherpy["Lat"], cities_weatherpy["Humidity"], marker="o")

plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("HumidityInWeatherPy.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(cities_weatherpy["Lat"], cities_weatherpy["Cloudiness"], marker="o")

plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("CloudinessInWeatherPy.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(cities_weatherpy["Lat"], cities_weatherpy["Wind Speed"], marker="o")

plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("WindSpeedInWeatherPy.png")

plt.show()

# %% [markdown]
# ## You must include a written description of three observable trends based on the data

# %% [markdown]
# From the ‘City Latitude vs. Max Temperature’ plot we can observe that the closure to the equator the higher the temperatures are. Also, the further from the equator the colder it gets.
# From the ‘City Latitude vs. Humidity’ and the ‘City Latitude vs. Cloudiness’ plot we do not see a significant correlation of humidity and cloudiness with altitude.
